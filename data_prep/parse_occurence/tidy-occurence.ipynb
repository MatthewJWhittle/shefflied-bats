# %%
from pyhere import here
import os

os.chdir(here())

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
in_filght_path = Path("data/raw/bats/All Yorkshire 2025 - In flight.xlsx")


bats_in_flight = pd.read_excel(in_filght_path,sheet_name="All Yorkshire In Flight")

bats_in_flight.head()
# Out:
#    ID Source                  Date GridRef6Fig Common name        Latin name  \
# 0   2    NYBG  1996-06-10 00:00:00    SE653577     Noctule  Nyctalus noctula
# 1   9    NYBG  1997-04-09 00:00:00    SE295772     Noctule  Nyctalus noctula
# 2  11    NYBG  1997-06-09 00:00:00    SE464354     Noctule  Nyctalus noctula
# 3  14    NYBG  1997-06-24 00:00:00    SE396670     Noctule  Nyctalus noctula
# 4  37    NYBG  1997-10-17 00:00:00    SE295772     Noctule  Nyctalus noctula
#
#   Activity type  Roosting?
# 0       Feeding  In Flight
# 1       Feeding  In Flight
# 2       Feeding  In Flight
# 3       Feeding  In Flight
# 4       Feeding  In Flight

# %%
roosting_path = Path("data/raw/bats/All Yorkshire 2025 - Roosting.xlsx")

bats_roosting = pd.read_excel(roosting_path,sheet_name="All Yorkshire 2025 - Roosting")

bats_roosting.head()
# Out:
#    ID Source        Date GridRef6Fig         Common name  \
# 0   3    NYBG 1996-06-17    SE514602  Common pipistrelle
# 1  12    NYBG 1997-06-17    SD997629             Noctule
# 2  13    NYBG 1997-06-18    SE269624  Common pipistrelle
# 3  16    NYBG 1997-06-26    SE593526             Noctule
# 4  20    NYBG 1997-07-26    SE667794  Common pipistrelle
#
#                   Latin name    Activity type Roosting? Unnamed: 8
# 0  Pipistrellus pipistrellus  Maternity Roost     Roost        NaN
# 1           Nyctalus noctula  Maternity Roost     Roost        NaN
# 2  Pipistrellus pipistrellus  Maternity Roost     Roost        NaN
# 3           Nyctalus noctula  Maternity Roost     Roost        NaN
# 4  Pipistrellus pipistrellus     Summer Roost     Roost        NaN

# %% [markdown]
# # General Tidying

# %%
# strip trailing whitespace from column names
bats_in_flight.columns = bats_in_flight.columns.str.strip()
bats_roosting.columns = bats_roosting.columns.str.strip()

# convert to snake case
import re
def snake_case(s):
    # remove punctuation
    s = re.sub(r'[^\w\s]', '', s)
    # replace whitespace with underscore
    s = re.sub(r"\s+", "_", s).lower()
    return s

bats_in_flight.columns = [snake_case(col) for col in bats_in_flight.columns]
bats_roosting.columns = [snake_case(col) for col in bats_roosting.columns]

# %%
bats_in_flight["source_file"] = in_filght_path.name
bats_roosting["source_file"] = roosting_path.name

bats = pd.concat([bats_in_flight, bats_roosting])

bats.rename(columns={"gridref6fig": "grid_reference", "unnamed_8" : "info"}, inplace=True)

# %%
bats.head()
# Out:
#    id source                 date grid_reference common_name  \
# 0   2   NYBG  1996-06-10 00:00:00       SE653577     Noctule
# 1   9   NYBG  1997-04-09 00:00:00       SE295772     Noctule
# 2  11   NYBG  1997-06-09 00:00:00       SE464354     Noctule
# 3  14   NYBG  1997-06-24 00:00:00       SE396670     Noctule
# 4  37   NYBG  1997-10-17 00:00:00       SE295772     Noctule
#
#          latin_name activity_type   roosting  \
# 0  Nyctalus noctula       Feeding  In Flight
# 1  Nyctalus noctula       Feeding  In Flight
# 2  Nyctalus noctula       Feeding  In Flight
# 3  Nyctalus noctula       Feeding  In Flight
# 4  Nyctalus noctula       Feeding  In Flight
#
#                            source_file info
# 0  All Yorkshire 2025 - In flight.xlsx  NaN
# 1  All Yorkshire 2025 - In flight.xlsx  NaN
# 2  All Yorkshire 2025 - In flight.xlsx  NaN
# 3  All Yorkshire 2025 - In flight.xlsx  NaN
# 4  All Yorkshire 2025 - In flight.xlsx  NaN

# %% [markdown]
# ## Overview of dataset

# %% [markdown]
# ### Duplicate IDs

# %%
bats["unique_id"] = bats["source"] + bats["id"].astype(str)

duplicate_ids = bats["unique_id"].duplicated().sum()

print(f"Number of duplicate IDs: {duplicate_ids}")
# Out:
# Number of duplicate IDs: 0

# %% [markdown]
# ### Species Names

# %%
bats["latin_name"] = bats["latin_name"].str.strip()

# %%
bats.latin_name.value_counts().sort_index()
# Out:
# Eptesicus serotinus              5
# Myotis brandtii                 60
# Myotis daubentonii             905
# Myotis mystacinus              295
# Myotis mystacinus/brandtii     151
# Myotis mysticanus                1
# Myotis nattereri               823
# Myotis sp.                     311
# Nyctalus leisleri              223
# Nyctalus noctula               893
# Nyctalus sp.                    39
# Pipistrellus nathusii           48
# Pipistrellus pipistrellus     7509
# Pipistrellus pygmaeus         1744
# Pipistrellus sp.              1518
# Plecotus auritus              1811
# Vespertilio murinus              1
# Vespertilionidae              1714
# Name: latin_name, dtype: int64

# %%
species_mapping = {
    "Myotis mysticanus": "Myotis mystacinus",
}

bats["latin_name"] = bats["latin_name"].replace(species_mapping)

bats.latin_name.value_counts().sort_index()
# Out:
# Eptesicus serotinus              5
# Myotis brandtii                 60
# Myotis daubentonii             905
# Myotis mystacinus              296
# Myotis mystacinus/brandtii     151
# Myotis nattereri               823
# Myotis sp.                     311
# Nyctalus leisleri              223
# Nyctalus noctula               893
# Nyctalus sp.                    39
# Pipistrellus nathusii           48
# Pipistrellus pipistrellus     7509
# Pipistrellus pygmaeus         1744
# Pipistrellus sp.              1518
# Plecotus auritus              1811
# Vespertilio murinus              1
# Vespertilionidae              1714
# Name: latin_name, dtype: int64

# %%
# Tag the latin names with the taxonomic level
taxonomic_levels = {
    "Pipistrellus pipistrellus": "species",
    "Pipistrellus pygmaeus": "species",
    "Nyctalus noctula": "species",
    "Vespertilionidae": "family",
    "Pipistrellus sp.": "genus",
    "Myotis daubentonii": "species",
    "Plecotus auritus": "species",
    "Myotis sp.": "genus",
    "Nyctalus leisleri": "species",
    "Myotis nattereri": "species",
    "Myotis mystacinus": "species",
    "Nyctalus sp.": "genus",
    "Myotis mystacinus/brandtii": "species_complex",
    "Pipistrellus nathusii": "species",
    "Myotis brandtii": "species",
    "Eptesicus serotinus": "species",
    "Vespertilio murinus": "species",
}

bats["taxonomic_level"] = bats["latin_name"].map(taxonomic_levels)

# raise a warning if any latin names are not in the mapping
missing_taxonomic_levels = bats["latin_name"][bats["taxonomic_level"].isnull()].unique()
if len(missing_taxonomic_levels) > 0:
    print(f"Warning: missing taxonomic levels for {missing_taxonomic_levels}")
# Out:
# Warning: missing taxonomic levels for [nan]

# %% [markdown]
# We're only concerned about modelling the species, so we can drop any taxonomic levels which are not species.

# %%
bats[bats.taxonomic_level.isin(["species"])]
# Out:
#              id source                 date grid_reference  \
# 0             2   NYBG  1996-06-10 00:00:00       SE653577
# 1             9   NYBG  1997-04-09 00:00:00       SE295772
# 2            11   NYBG  1997-06-09 00:00:00       SE464354
# 3            14   NYBG  1997-06-24 00:00:00       SE396670
# 4            37   NYBG  1997-10-17 00:00:00       SE295772
# ...         ...    ...                  ...            ...
# 11843  sybg7852   SYBG  2023-08-29 00:00:00     SK36908430
# 11844  sybg7853   SYBG  2023-09-26 00:00:00     SK36908430
# 11848  sybg7857   SYBG  2025-01-16 00:00:00   SK5346082911
# 11849  sybg7858   SYBG  2025-01-16 00:00:00   SK5310083068
# 11850  sybg7859   SYBG  2025-02-10 00:00:00   SE2798500890
#
#                common_name                 latin_name activity_type  \
# 0                  Noctule           Nyctalus noctula       Feeding
# 1                  Noctule           Nyctalus noctula       Feeding
# 2                  Noctule           Nyctalus noctula       Feeding
# 3                  Noctule           Nyctalus noctula       Feeding
# 4                  Noctule           Nyctalus noctula       Feeding
# ...                    ...                        ...           ...
# 11843   Common pipistrelle  Pipistrellus pipistrellus           NaN
# 11844   Common pipistrelle  Pipistrellus pipistrellus           NaN
# 11848       Natterer's bat           Myotis nattereri           NaN
# 11849  Soprano pipistrelle      Pipistrellus pygmaeus           NaN
# 11850        Leisler's bat          Nyctalus leisleri           NaN
#
#         roosting                          source_file info     unique_id  \
# 0      In Flight  All Yorkshire 2025 - In flight.xlsx  NaN         NYBG2
# 1      In Flight  All Yorkshire 2025 - In flight.xlsx  NaN         NYBG9
# 2      In Flight  All Yorkshire 2025 - In flight.xlsx  NaN        NYBG11
# 3      In Flight  All Yorkshire 2025 - In flight.xlsx  NaN        NYBG14
# 4      In Flight  All Yorkshire 2025 - In flight.xlsx  NaN        NYBG37
# ...          ...                                  ...  ...           ...
# 11843      Roost   All Yorkshire 2025 - Roosting.xlsx  NaN  SYBGsybg7852
# 11844      Roost   All Yorkshire 2025 - Roosting.xlsx  NaN  SYBGsybg7853
# 11848      Roost   All Yorkshire 2025 - Roosting.xlsx  NaN  SYBGsybg7857
# 11849      Roost   All Yorkshire 2025 - Roosting.xlsx  NaN  SYBGsybg7858
# 11850      Roost   All Yorkshire 2025 - Roosting.xlsx  NaN  SYBGsybg7859
#
#       taxonomic_level
# 0             species
# 1             species
# 2             species
# 3             species
# 4             species
# ...               ...
# 11843         species
# 11844         species
# 11848         species
# 11849         species
# 11850         species
#
# [14318 rows x 12 columns]

# %% [markdown]
# # Grid References

# %%
# do some basic tidying up of removing whitespace and special characters

def clean_grid_reference(grid_reference):
    """
    Clean a grid reference by:
    - Stripping whitespace
    - Converting to uppercase
    - Removing anything that isn't a letter, number or space
    - replacing multiple spaces with a single space
    """
    grid_reference = grid_reference.str.strip()
    grid_reference = grid_reference.str.upper()
    grid_reference = grid_reference.str.replace(r"[^A-Z0-9 ]", "")
    grid_reference = grid_reference.str.replace(r"\s+", " ")

    return grid_reference

bats["grid_reference"] = clean_grid_reference(bats["grid_reference"])
# Out:
# /var/folders/w6/z6wv9w5s4r77c8m0lp63lm1w0000gp/T/ipykernel_50643/3780871441.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   grid_reference = grid_reference.str.replace(r"[^A-Z0-9 ]", "")
# /var/folders/w6/z6wv9w5s4r77c8m0lp63lm1w0000gp/T/ipykernel_50643/3780871441.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   grid_reference = grid_reference.str.replace(r"\s+", " ")

# %%
import bng
import re
def check_grid_reference(grid_ref):
    if pd.isna(grid_ref) or not isinstance(grid_ref, str):
        return False
    pattern = r"^[A-Za-z]{2} ?\d{1,5} ?\d{1,5}$"
    return bool(re.match(pattern, grid_ref))

bats["grid_reference_valid"] = bats.grid_reference.apply(check_grid_reference)
bats[bats.grid_reference_valid == False][["source", "grid_reference"]].drop_duplicates()
# Out:
#       source  grid_reference
# 2021    EYBG  SE773116 57825
# 2280    EYBG  TA11021 128654
# 10557   SYBG             NaN

# %%
grid_reference_mappings = {
    "S 4811699289": "SK4811699289", # Checked address in grid ref finder
    "SK401964toSK393980": "SK396970", # Taken estimated middle point
    "SK41894978784": "SK4189478784", # Checked post code in grid ref finder
    "SK401964TOSK393980": "SK396970", # Taken estimated middle point}
    "SE773116 57825" : "SE 77311 57825",
}
# Replace the invalid grid references
bats.grid_reference.replace(grid_reference_mappings, inplace=True)

# %%
bats["grid_reference_valid"] = bats.grid_reference.apply(check_grid_reference)
bats[bats.grid_reference_valid == False][["source_file", "date", "source", "id", "grid_reference", "latin_name"]]
# Out:
#                               source_file                 date source  \
# 2021   All Yorkshire 2025 - Roosting.xlsx  2022-06-09 00:00:00   EYBG
# 2022   All Yorkshire 2025 - Roosting.xlsx  2022-06-06 00:00:00   EYBG
# 2023   All Yorkshire 2025 - Roosting.xlsx  2022-06-09 00:00:00   EYBG
# 2024   All Yorkshire 2025 - Roosting.xlsx  2022-07-17 00:00:00   EYBG
# 2025   All Yorkshire 2025 - Roosting.xlsx  2022-07-17 00:00:00   EYBG
# 2026   All Yorkshire 2025 - Roosting.xlsx  2022-07-17 00:00:00   EYBG
# 2280   All Yorkshire 2025 - Roosting.xlsx  2018-08-20 00:00:00   EYBG
# 10557  All Yorkshire 2025 - Roosting.xlsx  2020-01-12 00:00:00   SYBG
# 10558  All Yorkshire 2025 - Roosting.xlsx  2020-01-12 00:00:00   SYBG
# 10559  All Yorkshire 2025 - Roosting.xlsx  2020-01-12 00:00:00   SYBG
# 10726  All Yorkshire 2025 - Roosting.xlsx  2022-01-12 00:00:00   SYBG
# 10727  All Yorkshire 2025 - Roosting.xlsx  2022-01-12 00:00:00   SYBG
# 10852  All Yorkshire 2025 - Roosting.xlsx  2023-01-13 00:00:00   SYBG
# 10853  All Yorkshire 2025 - Roosting.xlsx  2023-01-13 00:00:00   SYBG
# 10854  All Yorkshire 2025 - Roosting.xlsx  2023-01-13 00:00:00   SYBG
# 10855  All Yorkshire 2025 - Roosting.xlsx  2023-01-13 00:00:00   SYBG
# 11143  All Yorkshire 2025 - Roosting.xlsx  1994-02-06 00:00:00   SYBG
# 11144  All Yorkshire 2025 - Roosting.xlsx  1994-02-06 00:00:00   SYBG
# 11145  All Yorkshire 2025 - Roosting.xlsx  1994-02-06 00:00:00   SYBG
# 11160  All Yorkshire 2025 - Roosting.xlsx  1998-02-08 00:00:00   SYBG
# 11161  All Yorkshire 2025 - Roosting.xlsx  1998-02-08 00:00:00   SYBG
# 11162  All Yorkshire 2025 - Roosting.xlsx  1998-02-08 00:00:00   SYBG
# 11163  All Yorkshire 2025 - Roosting.xlsx  1998-02-08 00:00:00   SYBG
# 11196  All Yorkshire 2025 - Roosting.xlsx  2019-02-10 00:00:00   SYBG
# 11197  All Yorkshire 2025 - Roosting.xlsx  2019-02-10 00:00:00   SYBG
# 11198  All Yorkshire 2025 - Roosting.xlsx  2019-02-10 00:00:00   SYBG
# 11207  All Yorkshire 2025 - Roosting.xlsx  2018-02-11 00:00:00   SYBG
# 11208  All Yorkshire 2025 - Roosting.xlsx  2018-02-11 00:00:00   SYBG
# 11209  All Yorkshire 2025 - Roosting.xlsx  2018-02-11 00:00:00   SYBG
# 11210  All Yorkshire 2025 - Roosting.xlsx  2018-02-11 00:00:00   SYBG
# 11218  All Yorkshire 2025 - Roosting.xlsx  2017-02-12 00:00:00   SYBG
# 11219  All Yorkshire 2025 - Roosting.xlsx  2017-02-12 00:00:00   SYBG
# 11220  All Yorkshire 2025 - Roosting.xlsx  2017-02-12 00:00:00   SYBG
# 11243  All Yorkshire 2025 - Roosting.xlsx  1998-12-13 00:00:00   SYBG
# 11244  All Yorkshire 2025 - Roosting.xlsx  1998-12-13 00:00:00   SYBG
# 11245  All Yorkshire 2025 - Roosting.xlsx  1998-12-13 00:00:00   SYBG
# 11269  All Yorkshire 2025 - Roosting.xlsx  1990-02-18 00:00:00   SYBG
# 11270  All Yorkshire 2025 - Roosting.xlsx  1990-02-18 00:00:00   SYBG
# 11271  All Yorkshire 2025 - Roosting.xlsx  1990-02-18 00:00:00   SYBG
# 11302  All Yorkshire 2025 - Roosting.xlsx  1994-02-20 00:00:00   SYBG
# 11303  All Yorkshire 2025 - Roosting.xlsx  1994-02-20 00:00:00   SYBG
# 11309  All Yorkshire 2025 - Roosting.xlsx  2017-01-21 00:00:00   SYBG
# 11310  All Yorkshire 2025 - Roosting.xlsx  2017-01-21 00:00:00   SYBG
# 11311  All Yorkshire 2025 - Roosting.xlsx  2017-01-21 00:00:00   SYBG
# 11312  All Yorkshire 2025 - Roosting.xlsx  2017-01-21 00:00:00   SYBG
# 11333  All Yorkshire 2025 - Roosting.xlsx  2010-01-24 00:00:00   SYBG
# 11334  All Yorkshire 2025 - Roosting.xlsx  2010-01-24 00:00:00   SYBG
# 11335  All Yorkshire 2025 - Roosting.xlsx  1999-01-24 00:00:00   SYBG
# 11336  All Yorkshire 2025 - Roosting.xlsx  1999-01-24 00:00:00   SYBG
# 11337  All Yorkshire 2025 - Roosting.xlsx  1999-01-24 00:00:00   SYBG
# 11338  All Yorkshire 2025 - Roosting.xlsx  1993-02-24 00:00:00   SYBG
# 11339  All Yorkshire 2025 - Roosting.xlsx  1993-02-24 00:00:00   SYBG
# 11340  All Yorkshire 2025 - Roosting.xlsx  1993-02-24 00:00:00   SYBG
# 11345  All Yorkshire 2025 - Roosting.xlsx  1997-01-26 00:00:00   SYBG
# 11346  All Yorkshire 2025 - Roosting.xlsx  1997-01-26 00:00:00   SYBG
# 11347  All Yorkshire 2025 - Roosting.xlsx  1997-01-26 00:00:00   SYBG
# 11356  All Yorkshire 2025 - Roosting.xlsx  2009-02-28 00:00:00   SYBG
#
#              id  grid_reference                  latin_name
# 2021        298  SE773116 57825            Plecotus auritus
# 2022        299  SE773116 57825   Pipistrellus pipistrellus
# 2023        300  SE773116 57825            Myotis nattereri
# 2024        301  SE773116 57825            Plecotus auritus
# 2025        302  SE773116 57825   Pipistrellus pipistrellus
# 2026        303  SE773116 57825            Myotis nattereri
# 2280        661  TA11021 128654   Pipistrellus pipistrellus
# 10557  sybg4515             NaN            Myotis nattereri
# 10558  sybg4516             NaN          Myotis daubentonii
# 10559  sybg4517             NaN            Plecotus auritus
# 10726  sybg4800             NaN            Myotis nattereri
# 10727  sybg4801             NaN  Myotis mystacinus/brandtii
# 10852  sybg5041             NaN            Myotis nattereri
# 10853  sybg5042             NaN          Myotis daubentonii
# 10854  sybg5043             NaN            Plecotus auritus
# 10855  sybg5044             NaN  Myotis mystacinus/brandtii
# 11143  sybg5740             NaN  Myotis mystacinus/brandtii
# 11144  sybg5741             NaN          Myotis daubentonii
# 11145  sybg5742             NaN                  Myotis sp.
# 11160  sybg5759             NaN            Plecotus auritus
# 11161  sybg5760             NaN  Myotis mystacinus/brandtii
# 11162  sybg5761             NaN            Myotis nattereri
# 11163  sybg5762             NaN          Myotis daubentonii
# 11196  sybg5950             NaN            Myotis nattereri
# 11197  sybg5951             NaN  Myotis mystacinus/brandtii
# 11198  sybg5952             NaN          Myotis daubentonii
# 11207  sybg6092             NaN            Myotis nattereri
# 11208  sybg6093             NaN            Vespertilionidae
# 11209  sybg6094             NaN          Myotis daubentonii
# 11210  sybg6095             NaN  Myotis mystacinus/brandtii
# 11218  sybg6111             NaN            Plecotus auritus
# 11219  sybg6112             NaN            Myotis nattereri
# 11220  sybg6113             NaN          Myotis daubentonii
# 11243  sybg6194             NaN          Myotis daubentonii
# 11244  sybg6195             NaN  Myotis mystacinus/brandtii
# 11245  sybg6196             NaN            Plecotus auritus
# 11269  sybg6539             NaN            Plecotus auritus
# 11270  sybg6540             NaN  Myotis mystacinus/brandtii
# 11271  sybg6541             NaN            Myotis nattereri
# 11302  sybg6580             NaN  Myotis mystacinus/brandtii
# 11303  sybg6581             NaN                  Myotis sp.
# 11309  sybg6630             NaN          Myotis daubentonii
# 11310  sybg6631             NaN            Plecotus auritus
# 11311  sybg6632             NaN            Myotis nattereri
# 11312  sybg6633             NaN                  Myotis sp.
# 11333  sybg6731             NaN            Myotis nattereri
# 11334  sybg6732             NaN                  Myotis sp.
# 11335  sybg6733             NaN          Myotis daubentonii
# 11336  sybg6734             NaN  Myotis mystacinus/brandtii
# 11337  sybg6735             NaN            Plecotus auritus
# 11338  sybg6736             NaN            Plecotus auritus
# 11339  sybg6737             NaN            Myotis nattereri
# 11340  sybg6738             NaN  Myotis mystacinus/brandtii
# 11345  sybg6849             NaN            Plecotus auritus
# 11346  sybg6850             NaN          Myotis daubentonii
# 11347  sybg6851             NaN  Myotis mystacinus/brandtii
# 11356  sybg6961             NaN            Myotis nattereri

# %%
bats.roosting.value_counts()
# Out:
# Roost        11851
# In flight     5902
# In Flight      530
# Name: roosting, dtype: int64

# %% [markdown]
# # Save

# %%
from shapely.geometry import Polygon, Point
from datetime import datetime
output_schema = {
    "source": str,
    "source_id": int,
    "unique_id": str,
    "latin_name": str,
    "common_name": str,
    "activity_type": str,
    "date": datetime,
    "x" : float,
    "y" : float,
    "resolution" : float,
    "geometry": Polygon,
}
