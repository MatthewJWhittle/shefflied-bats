# %%
from sdm.utils import set_project_wd
set_project_wd()
# Out:
# Current Working Directory: /Users/work/Data Science/sheffield-bats

# %%
from pathlib import Path
import geopandas as gpd
import json
import pandas as pd
from pipelines.GenerateAppData.main import points_to_grid_squares
import rioxarray as rxr

# %%
predictions_dir = Path("data/sdm_predictions")
predictions_files = list(predictions_dir.glob("*.tif"))

predictions = rxr.open_rasterio(predictions_files[0])
raster_bounds = predictions.rio.bounds()
predictions
# Out:
# <xarray.DataArray (band: 1, y: 563, x: 792)> Size: 2MB
# [445896 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 6kB 4.039e+05 4.04e+05 ... 4.83e+05 4.831e+05
#   * y            (y) float64 5kB 3.705e+05 3.706e+05 ... 4.267e+05 4.268e+05
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:             Area
#     STATISTICS_APPROXIMATE:    YES
#     STATISTICS_MAXIMUM:        1
#     STATISTICS_MEAN:           0.12116907098483
#     STATISTICS_MINIMUM:        4.5050383050693e-06
#     STATISTICS_STDDEV:         0.22072790456133
#     STATISTICS_VALID_PERCENT:  94.91
#     _FillValue:                -9999.0
#     scale_factor:              1.0
#     add_offset:                0.0

# %%
input_file = Path("data/processed/sybg-bats.parquet")
bats = gpd.read_parquet(input_file)  # type: gpd.GeoDataFrame

bats.head()
# Out:
#   grid_reference               species_raw activity_type  \
# 0       NZ115084        Common pipistrelle         Roost
# 1     NZ14640021          Pipistrellus sp.       Unknown
# 2     NZ20291106       Soprano pipistrelle       Unknown
# 3       NZ170014  Unidentified bat species         Roost
# 4       NZ185116  Unidentified bat species         Roost
#
#                                          source_data                 date  \
# 0  {"Recorder":"BCT\/NE","Date":1274054400000,"Gr...  2010-05-17 00:00:00
# 1  {"Recorder":"Giles Manners","Date":14043456000...  2014-07-03 00:00:00
# 2  {"Recorder":"Natural England Volunteer Bat Roo...  2013-11-28 00:00:00
# 3  {"Recorder":"BCT\/NE","Date":1283212800000,"Gr...  2010-08-31 00:00:00
# 4  {"Recorder":"BCT\/NE","Date":1242777600000,"Gr...  2009-05-20 00:00:00
#
#                   latin_name               common_name         genus  \
# 0  Pipistrellus pipistrellus        Common Pipistrelle  Pipistrellus
# 1           Pipistrellus sp.  Unidentified Pipistrelle  Pipistrellus
# 2      Pipistrellus pygmaeus       Soprano Pipistrelle  Pipistrellus
# 3                    Unknown          Unidentified Bat       Unknown
# 4                    Unknown          Unidentified Bat       Unknown
#
#           x         y  accuracy                       geometry  \
# 0  411550.0  508450.0     100.0  POINT (411550.000 508450.000)
# 1  414645.0  500215.0      10.0  POINT (414645.000 500215.000)
# 2  420295.0  511065.0      10.0  POINT (420295.000 511065.000)
# 3  417050.0  501450.0     100.0  POINT (417050.000 501450.000)
# 4  418550.0  511650.0     100.0  POINT (418550.000 511650.000)
#
#                                     grid_square_geom
# 0  POLYGON ((411600.000 508400.000, 411600.000 50...
# 1  POLYGON ((414650.000 500210.000, 414650.000 50...
# 2  POLYGON ((420300.000 511060.000, 420300.000 51...
# 3  POLYGON ((417100.000 501400.000, 417100.000 50...
# 4  POLYGON ((418600.000 511600.000, 418600.000 51...

# %%
bats.query("latin_name == 'Myotis nattereri' and activity_type == 'Roost'").explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9beb17dd74d855151b34045e9f39a372 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9beb17dd74d855151b34045e9f39a372&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9beb17dd74d855151b34045e9f39a372 = L.map(
#                 &quot;map_9beb17dd74d855151b34045e9f39a372&quot;,
#                 {
#                     center: [53.84601752868928, -1.3551537809173637],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9beb17dd74d855151b34045e9f39a372);
#
#
#
#
#
#             var tile_layer_6ed3567952e26759d8ae90b878a417da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6ed3567952e26759d8ae90b878a417da.addTo(map_9beb17dd74d855151b34045e9f39a372);
#
#
#             map_9beb17dd74d855151b34045e9f39a372.fitBounds(
#                 [[53.29903960987611, -1.7844390990305887], [54.39299544750245, -0.9258684628041387]],
#                 {}
#             );
#
#
#         function geo_json_44378e86c4c805b442b10f32d4d874cd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_44378e86c4c805b442b10f32d4d874cd_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_44378e86c4c805b442b10f32d4d874cd_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_44378e86c4c805b442b10f32d4d874cd_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_44378e86c4c805b442b10f32d4d874cd_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_44378e86c4c805b442b10f32d4d874cd.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_44378e86c4c805b442b10f32d4d874cd_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_44378e86c4c805b442b10f32d4d874cd = L.geoJson(null, {
#                 onEachFeature: geo_json_44378e86c4c805b442b10f32d4d874cd_onEachFeature,
#
#                 style: geo_json_44378e86c4c805b442b10f32d4d874cd_styler,
#                 pointToLayer: geo_json_44378e86c4c805b442b10f32d4d874cd_pointToLayer,
#         });
#
#         function geo_json_44378e86c4c805b442b10f32d4d874cd_add (data) {
#             geo_json_44378e86c4c805b442b10f32d4d874cd
#                 .addData(data);
#         }
#             geo_json_44378e86c4c805b442b10f32d4d874cd_add({&quot;bbox&quot;: [-1.7844390990305887, 53.29903960987611, -0.9258684628041387, 54.39299544750245], &quot;features&quot;: [{&quot;bbox&quot;: [-1.7844390990305887, 53.93559113659797, -1.7844390990305887, 53.93559113659797], &quot;geometry&quot;: {&quot;coordinates&quot;: [-1.7844390990305887, 53.93559113659797], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;199&quot;, &quot;properties&quot;: {&quot;accuracy&quot;: 100.0, &quot;activity_type&quot;: &quot;Roost&quot;, &quot;common_name&quot;: &quot;Natterer\u0027s Bat&quot;, &quot;date&quot;: &quot;2012-05-03 00:00:00&quot;, &quot;genus&quot;: &quot;Myotis&quot;, &quot;grid_reference&quot;: &quot;SE142488&quot;, &quot;latin_name&quot;: &quot;Myotis nattereri&quot;, &quot;source_data&quot;

# %%
assert (
    bats.crs == 27700
), "The bats dataframe must be in British National Grid to allow records to be filtered by raster bounds"
bats = bats[bats.accuracy <= 100]

source_data = bats.source_data.apply(json.loads).apply(pd.Series)

bats_gdf_full = bats.join(source_data)
bats_gdf_full = bats_gdf_full[
    [
        "grid_reference",
        "species_raw",
        "activity_type",
        "source_data",
        "date",
        "latin_name",
        "common_name",
        "genus",
        "x",
        "y",
        "accuracy",
        "Recorder",
        "Notes",
        "Evidence",
        "Source",
        "row_id",
        "geometry",
    ]
]


# Drop the records that are outside the raster bounds
bats_gdf_full = bats_gdf_full.cx[
    raster_bounds[0] : raster_bounds[2], raster_bounds[1] : raster_bounds[3]
]
## This was the issue vv - index mismatch
#bats_gdf_full.reset_index(drop=True, inplace=True)


bats_gdf_full["geometry"] = points_to_grid_squares(
    bats_gdf_full.geometry,
    grid_size=250,
    origin=(0,0),
)

# %%
bats_gdf_full.query("latin_name == 'Myotis nattereri' and activity_type == 'Roost'").explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b197deb357c56a41c99a49852f6d984a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b197deb357c56a41c99a49852f6d984a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b197deb357c56a41c99a49852f6d984a = L.map(
#                 &quot;map_b197deb357c56a41c99a49852f6d984a&quot;,
#                 {
#                     center: [53.496687623341785, -1.394328484595801],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b197deb357c56a41c99a49852f6d984a);
#
#
#
#
#
#             var tile_layer_0a887e0feaf23aec03889b0668c26987 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0a887e0feaf23aec03889b0668c26987.addTo(map_b197deb357c56a41c99a49852f6d984a);
#
#
#             map_b197deb357c56a41c99a49852f6d984a.fitBounds(
#                 [[53.29768789351296, -1.7111301044797214], [53.69568735317062, -1.0775268647118807]],
#                 {}
#             );
#
#
#         function geo_json_49fa611b817f3ba43c36f9fc784ca33d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_49fa611b817f3ba43c36f9fc784ca33d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_49fa611b817f3ba43c36f9fc784ca33d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_49fa611b817f3ba43c36f9fc784ca33d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_49fa611b817f3ba43c36f9fc784ca33d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_49fa611b817f3ba43c36f9fc784ca33d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_49fa611b817f3ba43c36f9fc784ca33d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_49fa611b817f3ba43c36f9fc784ca33d = L.geoJson(null, {
#                 onEachFeature: geo_json_49fa611b817f3ba43c36f9fc784ca33d_onEachFeature,
#
#                 style: geo_json_49fa611b817f3ba43c36f9fc784ca33d_styler,
#                 pointToLayer: geo_json_49fa611b817f3ba43c36f9fc784ca33d_pointToLayer,
#         });
#
#         function geo_json_49fa611b817f3ba43c36f9fc784ca33d_add (data) {
#             geo_json_49fa611b817f3ba43c36f9fc784ca33d
#                 .addData(data);
#         }
#             geo_json_49fa611b817f3ba43c36f9fc784ca33d_add({&quot;bbox&quot;: [-1.7111301044797214, 53.29768789351296, -1.0775268647118807, 53.69568735317062], &quot;features&quot;: [{&quot;bbox&quot;: [-1.7111301044797214, 53.521078783408875, -1.7073441307525423, 53.52333487990876], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.7073595061485136, 53.521078783408875], [-1.7073441307525423, 53.523325783574485], [-1.711114928448461, 53.52333487990876], [-1.7111301044797214, 53.5210878786768], [-1.7073595061485136, 53.521078783408875]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;115&quot;, &quot;properties&quot;: {&quot;Evidence&quot;: null, &quot;Notes&quot;: null, &quot;Recorder&quot;: &quot;Eric Bennett&quot;, &quot;Source&quot;: &quot;EB Records&quot;, &quot;accuracy&quot;: 100.0,

# %%
# then group by the geometry, latin_name and activity_type and count the number of records
bats_gdf_full = (
    bats_gdf_full.groupby(["geometry", "latin_name", "activity_type"])
    .size()
    .reset_index(name="count")
)
# convert back to geodataframe as this is lost during group by
bats_gdf_full = gpd.GeoDataFrame(bats_gdf_full, geometry="geometry", crs=27700)
